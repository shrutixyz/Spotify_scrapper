# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://spotifycharts.com/regional"

res = requests.get(url)
soup = BeautifulSoup(res.text)
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>\n  <title>\n   Spotify Charts\n  </title>\n  <meta content="Spotify Charts" property="og:title"/>\n  <meta content="website" property="og:type"/>\n  <meta content="https://www.spotifycharts.com/" property="og:url"/>\n  <meta content="http://d2c87l0yth4zbw-2.global.ssl.fastly.net/i/_global/open-graph-default.png" property="og:image"/>\n  <meta content="Spotify is all the music you’ll ever need." property="og:description"/>\n  <meta content="Spotify is all the music you’ll ever need." name="description"/>\n  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>\n  <link href="/images/touch-icon-144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>\n  <link href="/images/touch-icon-114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>\n  <link href="/images/touch-icon-72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>\n  <link href="/images/touch-icon-57.png" rel="apple-touch-icon-precomposed"/>\n  <link href="/css/app.css" rel="stylesheet" type="text/css"/>\n  <script>\n   window.log = function () {\n                log.history = log.history || [];\n                log.history.push(arguments);\n                if (this.console) {\n                    console.log(Array.prototype.slice.call(arguments))\n                }\n            };\n  </script>\n  <script>\n   var ROUTE_PARAMS = {type: \'regional\', country: \'global\', recurrence: \'daily\', date: \'2020-08-09\'};\n  </script>\n </head>\n <body>\n  <!--[if lt IE 9]>\n          <p class="browsehappy">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>\n        <![endif]-->\n  <div id="content">\n   <div>\n    <header class="header">\n     <div class="container">\n      <a class="header-csv" download="" href="/regional/global/daily/latest/download">\n       Download to CSV\n      </a>\n      <h1 class="header-logo">\n       <a href="/">\n        Spotify\n       </a>\n      </h1>\n      <h2 class="header-title">\n       Charts\n      </h2>\n     </div>\n    </header>\n    <div class="wrapper">\n     <div class="container">\n      <span>\n       <div class="wrapper">\n        <div class="container">\n         <div class="chart-filters">\n          <label>\n           Filter by\n          </label>\n          <a class="menu-button">\n           Menu\n          </a>\n          <div class="chart-filters-list">\n           <div class="responsive-select" data-type="country">\n            <div class="responsive-select-value">\n             Global\n            </div>\n            <ul>\n             <li class="selected" data-value="global">\n              Global\n             </li>\n             <li class="" data-value="us">\n              United States\n             </li>\n             <li class="" data-value="gb">\n              United Kingdom\n             </li>\n             <li class="" data-value="ad">\n              Andorra\n             </li>\n             <li class="" data-value="ar">\n              Argentina\n             </li>\n             <li class="" data-value="at">\n              Austria\n             </li>\n             <li class="" data-value="au">\n              Australia\n             </li>\n             <li class="" data-value="be">\n              Belgium\n             </li>\n             <li class="" data-value="bg">\n              Bulgaria\n             </li>\n             <li class="" data-value="bo">\n              Bolivia\n             </li>\n             <li class="" data-value="br">\n              Brazil\n             </li>\n             <li class="" data-value="ca">\n              Canada\n             </li>\n             <li class="" data-value="ch">\n              Switzerland\n             </li>\n             <li class="" data-value="cl">\n              Chile\n             </li>\n             <l ...

# %%
def getSongs():
  song_list=[]
  tracks=soup.find_all("td", attrs ={"class": "chart-table-track"})
  for i in range(200):
    j = i+1
    t = tracks[i]
    text = t.getText()
    stripped = text.strip()
    li= stripped.split("\n")
    l= str(j)+" "+"  ".join(li)
    song_list.append(l)

  return song_list

# %%
top_10 = (getSongs())
top_10 = map(lambda x:x.lower(), top_10)
output = list(top_10)

# %%
output[:50]
# Out:
# ['1 savage love (laxed - siren beat)  by jawsh 685',
#  '2 rockstar (feat. roddy ricch)  by dababy',
#  '3 wap (feat. megan thee stallion)  by cardi b',
#  '4 blinding lights  by the weeknd',
#  '5 watermelon sugar  by harry styles',
#  '6 roses - imanbek remix  by saint jhn',
#  '7 smile (with the weeknd)  by juice wrld',
#  '8 breaking me  by topic',
#  '9 come & go (with marshmello)  by juice wrld',
#  '10 un dia (one day) (feat. tainy)  by j balvin',
#  '11 dance monkey  by tones and i',
#  '12 la jeepeta - remix  by nio garcia',
#  '13 wishing well  by juice wrld',
#  '14 death bed (coffee for your head)  by powfu',
#  '15 my future  by billie eilish',
#  '16 caramelo  by ozuna',
#  '17 cardigan  by taylor swift',
#  '18 agua (with j balvin) - music from "sponge on the run" movie  by tainy',
#  '19 ily (i love you baby) (feat. emilee)  by surf mesa',
#  '20 mood swings (feat. lil tjay)  by pop smoke',
#  '21 rain on me (with ariana grande)  by lady gaga',
#  '22 mamacita  by black eyed peas',
#  '23 tattoo - remix with camilo  by rauw alejandro',
#  '24 la curiosidad  by jay wheeler',
#  '25 head & heart (feat. mnek)  by joel corry',
#  '26 blueberry faygo  by lil mosey',
#  '27 relación  by sech',
#  '28 break my heart  by dua lipa',
#  '29 exile (feat. bon iver)  by taylor swift',
#  '30 whats poppin (feat. dababy, tory lanez & lil wayne) - remix  by jack harlow',
#  '31 someone you loved  by lewis capaldi',
#  "32 don't start now  by dua lipa",
#  '33 toosie slide  by drake',
#  '34 the woo (feat. 50 cent & roddy ricch)  by pop smoke',
#  '35 for the night (feat. lil baby & dababy)  by pop smoke',
#  '36 djadja (feat. maluma) - remix  by aya nakamura',
#  '37 party girl  by staysolidrocky',
#  '38 stuck with u (with justin bieber)  by ariana grande',
#  '39 before you go  by lewis capaldi',
#  '40 how you like that  by blackpink',
#  '41 go crazy  by chris brown',
#  '42 mamichula - con nicki nicole  by trueno',
#  '43 greece (feat. drake)  by dj khaled',
#  '44 ay, dios mío!  by karol g',
#  '45 tkn (feat. travis scott)  by rosalía',
#  '46 the box  by roddy ricch',
#  '47 kings & queens  by ava max',
#  '48 popstar (feat. drake)  by dj khaled',
#  '49 intentions (feat. quavo)  by justin bieber',
#  '50 supalonely  by benee']

# %%
# Out:
# 0
# ['[]']

# %%
# Out:
# "Stuck with U (with Justin Bieber)  by Ariana Grande'"

# %%
def getInput(number,artist):
  test_list = output[:number]

  subs = artist

  res = list(filter(lambda x: subs in x, test_list)) 
  res_str= str(res)
  if(len(res)!=0):
    split_res = res_str.split(",")

  

    for st in range(len(split_res)):
      song=split_res[st][:-1].strip().split(" ")
      s=" ".join(song[1:]).strip("\'").title()
      print(f"WE FOUND A MATCH: {s}")
      pos=song[0].strip("['")
      print(f"Your favourite song is at {pos}!!!")

    with open("topn.txt","w") as file:
      m=0
      for m in range(number):
      
        k=output[m]
        file.write(str(k).title())
    
        file.write("\n")
  else:
    print("Sorry! Couldn't make it on top of charts :(")

# %%
number = int(input("Enter the boundaries in which you want to search(max:200): "))
artist = input("Enter the name of you favourite artist or song:")
artist=artist.lower()

getInput(number,artist)
# Out:
# Enter the boundaries in which you want to search: 10
# Enter the name of you favourite artist or song:harerf
# Sorry! Couldn't make it on top of charts :(
